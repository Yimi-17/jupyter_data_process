# %%
import empiricaldist
import janitor
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats
import seaborn as sns
import sklearn.metrics
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats as ss
import session_info

# %%
# %matplotlib inline
sns.set_style(style='whitegrid')
sns.set_context(context='notebook')
plt.rcParams['figure.figsize'] = (11,9.4)

git_color = {
    'Adelie':'#ff6602ff',
    'Gentoo':'#0f7175ff',
    'Chinstrap':'#c65dc9ff',
    'Torgersen': '#955FC8', 
    'Biscoe': '#94e2c3', 
    'Dream': '#345469',
}

# %%
preprocess_git_df = pd.read_csv('cp-10k-GH-GetRepos-V3 - Main.csv') # preprocessed Data
preprocess_git_df.head()
# Out:
#    ID  Unnamed: 1                    Name  \
# 0   1         NaN                    grit
# 1  27         NaN                rubinius
# 2  28         NaN                     god
# 3  42         NaN  restful-authentication
# 4  43         NaN           attachment_fu
#
#                                                  URL  Lang  Estrellas Commits  \
# 0                    https://github.com/mojombo/grit  Ruby       1965   0XNaN
# 1               https://github.com/rubinius/rubinius     C       3044   0XNaN
# 2                     https://github.com/mojombo/god  Ruby       2204   0XNaN
# 3  https://github.com/technoweenie/restful-authen...  Ruby       1573   0XNaN
# 4      https://github.com/technoweenie/attachment_fu  Ruby       1024   0XNaN
#
#    Forks  Subs  Issues    Size                Create                Update  \
# 0    536    72      30    7954  2007-10-29T14:37:16Z  2023-05-26T17:01:46Z
# 1    604   103      15  168069  2008-01-12T16:46:52Z  2023-05-31T19:42:48Z
# 2    521    87     432    2639  2008-01-13T05:16:23Z  2023-05-31T15:25:20Z
# 3    277    17      27    1208  2008-01-14T14:44:23Z  2023-04-19T10:32:14Z
# 4    324    10      35    1008  2008-01-14T14:51:56Z  2023-05-10T13:56:55Z
#
#               pushed_at          HR        FR  DR  8488726
# 0  2020-10-01T03:55:32Z  4:13:40 AM  6/2/2023 NaN      NaN
# 1  2023-05-09T19:49:03Z  4:38:16 PM  6/2/2023 NaN      NaN
# 2  2022-01-12T14:06:16Z  4:38:17 PM  6/2/2023 NaN      NaN
# 3  2015-07-31T22:25:04Z  4:38:23 PM  6/2/2023 NaN      NaN
# 4  2017-03-28T00:48:29Z  4:38:23 PM  6/2/2023 NaN      NaN

# %%
preprocess_git_df.shape
# Out:
# (10729, 18)

# %%
preprocess_git_df.isnull().sum()
# Out:
# ID                0
# Unnamed: 1    10729
# Name              0
# URL               0
# Lang            235
# Estrellas         0
# Commits           0
# Forks             0
# Subs              0
# Issues            0
# Size              0
# Create            0
# Update            0
# pushed_at         0
# HR                0
# FR                0
# DR             3955
# 8488726       10729
# dtype: int64

# %%
preprocess_git_df.dtypes
# Out:
# ID              int64
# Unnamed: 1    float64
# Name           object
# URL            object
# Lang           object
# Estrellas       int64
# Commits        object
# Forks           int64
# Subs            int64
# Issues          int64
# Size            int64
# Create         object
# Update         object
# pushed_at      object
# HR             object
# FR             object
# DR            float64
# 8488726       float64
# dtype: object

# %% [markdown]
# #df_git = preprocess_git_df.dropna() Hay variables que tienen los datos vacios por eso si ejecuto este comando se borra toda la data
# #df_git

# %%
# Seleccionar solo las columnas requeridas
git_df = preprocess_git_df[['Name', 'URL', 'Lang', 'Estrellas', 'Forks', 'Subs', 'Issues', 'Size']] # Se selecciona las columnas especificas y se almacenaron en un dataframe llamado git_df

# %%
git_df #Para imprimir los valores del nuevo dataframe
# Out:
#                          Name  \
# 0                        grit
# 1                    rubinius
# 2                         god
# 3      restful-authentication
# 4               attachment_fu
# ...                       ...
# 10724                     zed
# 10725                 LINQKit
# 10726            gt-nlp-class
# 10727            realm-dotnet
# 10728                 xbanish
#
#                                                      URL        Lang  \
# 0                        https://github.com/mojombo/grit        Ruby
# 1                   https://github.com/rubinius/rubinius           C
# 2                         https://github.com/mojombo/god        Ruby
# 3      https://github.com/technoweenie/restful-authen...        Ruby
# 4          https://github.com/technoweenie/attachment_fu        Ruby
# ...                                                  ...         ...
# 10724                      https://github.com/zedapp/zed  JavaScript
# 10725           https://github.com/scottksmith95/LINQKit          C#
# 10726    https://github.com/jacobeisenstein/gt-nlp-class         TeX
# 10727              https://github.com/realm/realm-dotnet          C#
# 10728                     https://github.com/jcs/xbanish           C
#
#        Estrellas  Forks  Subs  Issues    Size
# 0           1965    536    72      30    7954
# 1           3044    604   103      15  168069
# 2           2204    521    87     432    2639
# 3           1573    277    17      27    1208
# 4           1024    324    10      35    1008
# ...          ...    ...   ...     ...     ...
# 10724       2170    171    65     180    5777
# 10725       1497    159    52      40    3695
# 10726       4825   1055   323       2  331077
# 10727       1189    164    75     137   81624
# 10728        502     63    16      16      40
#
# [10729 rows x 8 columns]

# %%
#Muestra un resumende variables con valores nulos
git_df.isnull().any()
# Out:
# Name         False
# URL          False
# Lang          True
# Estrellas    False
# Forks        False
# Subs         False
# Issues       False
# Size         False
# dtype: bool

# %%
#De tener observaciones con valores nulos, ¿cuantas tenemos por cada variable?
git_df.isnull().sum()
# Out:
# Name           0
# URL            0
# Lang         235
# Estrellas      0
# Forks          0
# Subs           0
# Issues         0
# Size           0
# dtype: int64

# %%
#¿Cuántos valores nulos tenemos en total en el conjunto de datos?
git_df.isnull().sum().sum()
# Out:
# 235

# %%
# ¿Cual es la proporcion de valores nulos por cada variable?
git_df.isnull().melt()
# Out:
#       variable  value
# 0         Name  False
# 1         Name  False
# 2         Name  False
# 3         Name  False
# 4         Name  False
# ...        ...    ...
# 85827     Size  False
# 85828     Size  False
# 85829     Size  False
# 85830     Size  False
# 85831     Size  False
#
# [85832 rows x 2 columns]

# %%
#Lo pasamos a un grafico
git_df.isnull().melt().pipe(
    lambda df: (
        sns.displot(
            data=df,y='variable',hue='value',multiple='fill',
            aspect=2
        )

    )

)

# %%
#¿Cómo podemos visualizar los valores nulos en todo el conjunto de datos?
git_df.isnull(). transpose()
# Out:
#            0      1      2      3      4      5      6      7      8      \
# Name       False  False  False  False  False  False  False  False  False
# URL        False  False  False  False  False  False  False  False  False
# Lang       False  False  False  False  False  False  False  False  False
# Estrellas  False  False  False  False  False  False  False  False  False
# Forks      False  False  False  False  False  False  False  False  False
# Subs       False  False  False  False  False  False  False  False  False
# Issues     False  False  False  False  False  False  False  False  False
# Size       False  False  False  False  False  False  False  False  False
#
#            9      ...  10719  10720  10721  10722  10723  10724  10725  10726  \
# Name       False  ...  False  False  False  False  False  False  False  False
# URL        False  ...  False  False  False  False  False  False  False  False
# Lang       False  ...  False  False  False  False  False  False  False  False
# Estrellas  False  ...  False  False  False  False  False  False  False  False
# Forks      False  ...  False  False  False  False  False  False  False  False
# Subs       False  ...  False  False  False  False  False  False  False  False
# Issues     False  ...  False  False  False  False  False  False  False  False
# Size       False  ...  False  False  False  False  False  False  False  False
#
#            10727  10728
# Name       False  False
# URL        False  False
# Lang       False  False
# Estrellas  False  False
# Forks      False  False
# Subs       False  False
# Issues     False  False
# Size       False  False
#
# [8 rows x 10729 columns]

# %%
#Visualizamos con seaborm
git_df.isnull(). transpose().pipe(
    lambda df: (
        sns. heatmap(
        data=df

            )

        )

    )
#Se visualiza varias lienas blancas en la columna lang
# Out:
# <Axes: >

# %%
#¿Cuántas observaciones perdemos si eliminamos los datos faltantes?
git_df_clean=git_df.dropna()
git_df_clean
#Con esto tenemos un dataset sin valores nulos
# Out:
#                          Name  \
# 0                        grit
# 1                    rubinius
# 2                         god
# 3      restful-authentication
# 4               attachment_fu
# ...                       ...
# 10724                     zed
# 10725                 LINQKit
# 10726            gt-nlp-class
# 10727            realm-dotnet
# 10728                 xbanish
#
#                                                      URL        Lang  \
# 0                        https://github.com/mojombo/grit        Ruby
# 1                   https://github.com/rubinius/rubinius           C
# 2                         https://github.com/mojombo/god        Ruby
# 3      https://github.com/technoweenie/restful-authen...        Ruby
# 4          https://github.com/technoweenie/attachment_fu        Ruby
# ...                                                  ...         ...
# 10724                      https://github.com/zedapp/zed  JavaScript
# 10725           https://github.com/scottksmith95/LINQKit          C#
# 10726    https://github.com/jacobeisenstein/gt-nlp-class         TeX
# 10727              https://github.com/realm/realm-dotnet          C#
# 10728                     https://github.com/jcs/xbanish           C
#
#        Estrellas  Forks  Subs  Issues    Size
# 0           1965    536    72      30    7954
# 1           3044    604   103      15  168069
# 2           2204    521    87     432    2639
# 3           1573    277    17      27    1208
# 4           1024    324    10      35    1008
# ...          ...    ...   ...     ...     ...
# 10724       2170    171    65     180    5777
# 10725       1497    159    52      40    3695
# 10726       4825   1055   323       2  331077
# 10727       1189    164    75     137   81624
# 10728        502     63    16      16      40
#
# [10494 rows x 8 columns]

# %%
git_df_clean.describe() #Este comando generará un resumen que incluye conteo, media, desviación estándar, mínimo, percentiles (25%, 50%, 75%) y máximo para cada columna numérica en tu DataFrame git_df
# Out:
#            Estrellas          Forks          Subs        Issues          Size
# count   10494.000000   10494.000000  10494.000000  10494.000000  1.049400e+04
# mean     2901.875834     675.513627    122.482085    100.505336  5.944172e+04
# std      6458.076621    2404.367236    242.850721    339.649557  5.788385e+05
# min       500.000000       0.000000      3.000000      0.000000  2.000000e+00
# 25%       718.000000     134.000000     37.000000     11.000000  6.430000e+02
# 50%      1192.500000     255.000000     64.000000     32.000000  2.911500e+03
# 75%      2539.500000     535.750000    121.000000     85.000000  1.783950e+04
# max    165201.000000  136205.000000   8221.000000  16067.000000  3.247060e+07

# %%
#describe solo muestra las variables numerias
#Agregamos all para mostrar todas las varibales
git_df_clean.describe(include='all')
# Out:
#             Name                                      URL        Lang  \
# count      10494                                    10494       10494
# unique     10226                                    10489         132
# top     dotfiles  https://github.com/mislav/will_paginate  JavaScript
# freq          22                                        2        2289
# mean         NaN                                      NaN         NaN
# std          NaN                                      NaN         NaN
# min          NaN                                      NaN         NaN
# 25%          NaN                                      NaN         NaN
# 50%          NaN                                      NaN         NaN
# 75%          NaN                                      NaN         NaN
# max          NaN                                      NaN         NaN
#
#             Estrellas          Forks          Subs        Issues          Size
# count    10494.000000   10494.000000  10494.000000  10494.000000  1.049400e+04
# unique            NaN            NaN           NaN           NaN           NaN
# top               NaN            NaN           NaN           NaN           NaN
# freq              NaN            NaN           NaN           NaN           NaN
# mean      2901.875834     675.513627    122.482085    100.505336  5.944172e+04
# std       6458.076621    2404.367236    242.850721    339.649557  5.788385e+05
# min        500.000000       0.000000      3.000000      0.000000  2.000000e+00
# 25%        718.000000     134.000000     37.000000     11.000000  6.430000e+02
# 50%       1192.500000     255.000000     64.000000     32.000000  2.911500e+03
# 75%       2539.500000     535.750000    121.000000     85.000000  1.783950e+04
# max     165201.000000  136205.000000   8221.000000  16067.000000  3.247060e+07

# %%
#Solo las numéricas
git_df_clean.describe(include=[np.number])
# Out:
#            Estrellas          Forks          Subs        Issues          Size
# count   10494.000000   10494.000000  10494.000000  10494.000000  1.049400e+04
# mean     2901.875834     675.513627    122.482085    100.505336  5.944172e+04
# std      6458.076621    2404.367236    242.850721    339.649557  5.788385e+05
# min       500.000000       0.000000      3.000000      0.000000  2.000000e+00
# 25%       718.000000     134.000000     37.000000     11.000000  6.430000e+02
# 50%      1192.500000     255.000000     64.000000     32.000000  2.911500e+03
# 75%      2539.500000     535.750000    121.000000     85.000000  1.783950e+04
# max    165201.000000  136205.000000   8221.000000  16067.000000  3.247060e+07

# %%
#Solo categóricas - 1
git_df_clean.describe(include=object)
# Out:
#             Name                                      URL        Lang
# count      10494                                    10494       10494
# unique     10226                                    10489         132
# top     dotfiles  https://github.com/mislav/will_paginate  JavaScript
# freq          22                                        2        2289

# %%
#¿Cómo visualizar los conteos?
git_df_clean.Lang.value_counts()
# Out:
# Lang
# JavaScript    2289
# Python        1292
# Ruby          1061
# Java           867
# C              718
#               ...
# Mako             1
# Oz               1
# DM               1
# LLVM             1
# Awk              1
# Name: count, Length: 132, dtype: int64

# %%
#Para graficar Pandas
git_df_clean.Lang. value_counts().plot(
    figsize=(20,12),
    kind='bar'

)
# Out:
# <Axes: xlabel='Lang'>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 12))  # Definir el tamaño de la figura
git_df_clean['Lang'].value_counts().plot(kind='bar')
plt.xlabel('Lenguaje de Programación')
plt.ylabel('Cantidad')
plt.title('Cantidad de Proyectos por Lenguaje de Programación')
plt.xticks(rotation=45)  # Rotar las etiquetas del eje x para que sean legibles
plt.tight_layout()  # Ajustar el diseño para evitar superposiciones
plt.show()

# %% [markdown]
# # Medidas de tendencia central

# %% [markdown]
# # Obtención de medidas de dispersión

# %%
#¿Qué tipo de dato son las variables del conjunto de datos?
git_df.dtypes
# Out:
# Name         object
# URL          object
# Lang         object
# Estrellas     int64
# Forks         int64
# Subs          int64
# Issues        int64
# Size          int64
# dtype: object

# %%
#Cuantas variables de cada tipo
git_df.dtypes.value_counts()
# Out:
# int64     5
# object    3
# Name: count, dtype: int64

# %%
#¿Cuántas variables y observaciones tenemos en el conjunto de datos?
git_df.shape
# Out:
# (10729, 8)

# %% [markdown]
# # Obtención de medidas de dispersión

# %%
#¿Cuál es el valor máximo de las variables?
git_df.max(numeric_only=True)
#Pasamos numeric_only porque solo nos interesa los numeros
# Out:
# Estrellas      165201
# Forks          136205
# Subs             8221
# Issues          16067
# Size         32903189
# dtype: int64

# %%
#¿Cuál es el valor mínimo de las variables?
git_df.min(numeric_only=True)
# Out:
# Estrellas    500
# Forks          0
# Subs           3
# Issues         0
# Size           1
# dtype: int64

# %%
#¿Cuál es el rango de las variables?
git_df.max(numeric_only=True)-git_df.min(numeric_only=True)
# Out:
# Estrellas      164701
# Forks          136205
# Subs             8218
# Issues          16067
# Size         32903188
# dtype: int64

# %%
#¿Cual es la desviacion estandar de Las variables?
git_df.std(numeric_only=True)
# Out:
# Estrellas      6581.354725
# Forks          2520.291297
# Subs            244.849387
# Issues          341.241278
# Size         702007.714782
# dtype: float64

# %%
#¿Cual es el rango intercuartilico?
git_df.quantile(0.25, numeric_only=True)
# Out:
# Estrellas    718.0
# Forks        134.0
# Subs          37.0
# Issues        11.0
# Size         627.0
# Name: 0.25, dtype: float64

# %%
#Rango intercuatilico
(git_df.quantile(0.75, numeric_only=True)
-git_df.quantile(0.25, numeric_only=True))
# Out:
# Estrellas     1831.0
# Forks          404.0
# Subs            85.0
# Issues          73.0
# Size         17158.0
# dtype: float64

# %%
#Para verlo en forma mas visual
(
git_df.quantile(q=[0.75,0.50,0.25], numeric_only=True)
. transpose()
. rename_axis('variable')
.reset_index().assign(
iqr=lambda df: df[0.75]-df[0.25]
)
)
# Out:
#     variable     0.75     0.5   0.25      iqr
# 0  Estrellas   2549.0  1193.0  718.0   1831.0
# 1      Forks    538.0   255.0  134.0    404.0
# 2       Subs    122.0    65.0   37.0     85.0
# 3     Issues     84.0    31.0   11.0     73.0
# 4       Size  17785.0  2858.0  627.0  17158.0

# %%
#Histograma
sns.histplot(
    data=git_df,
    x='flipper_length_mm
)
#En el grafico el ancho de clase es de 5
# Out:
#   Cell In[49], line 4
#     x='flipper_length_mm
#       ^
# SyntaxError: unterminated string literal (detected at line 4)
