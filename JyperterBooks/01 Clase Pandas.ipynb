# %%
import pandas as pd

# %%
#Creamos un Lista y Lo pasamos a Series
#por defecto se asigna el indice
interm=pd. Series(['Messi', 'Suarez', 'Busquets', 'Jordi Alva', 'Campana'])
interm
# Out:
# 0         Messi
# 1        Suarez
# 2      Busquets
# 3    Jordi Alva
# 4       Campana
# dtype: object

# %%
interm=pd. Series(['Messi', 'Suarez', 'Busquets', 'Jordi Alva', 'Campana', 'Calender'],
                index=['10','9','5','18','8','1'])
interm
# Out:
# 10         Messi
# 9         Suarez
# 5       Busquets
# 18    Jordi Alva
# 8        Campana
# 1       Calender
# dtype: object

# %%
dicc={10:'Messi', 9:'Suarez', 5:'Busquets', 18:'Jordi Alva', 8:'Campana', 1:'Calender'}
dicc
# Out:
# {10: 'Messi',
#  9: 'Suarez',
#  5: 'Busquets',
#  18: 'Jordi Alva',
#  8: 'Campana',
#  1: 'Calender'}

# %%
dataframe1=pd.Series(dicc)
dataframe1
# Out:
# 10         Messi
# 9         Suarez
# 5       Busquets
# 18    Jordi Alva
# 8        Campana
# 1       Calender
# dtype: object

# %%
dataframe1[10]
# Out:
# 'Messi'

# %%
dataframe1[0:2]
# Out:
# 10     Messi
# 9     Suarez
# dtype: object

# %%
#Importamos un CSV
df1 = pd.read_csv('bestsellers-with-categories.csv')
df1.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
df2 = pd.read_csv('Beneficiarios-del-Bono-del-Pescador-2024.csv')
df2.head()
# Out:
#      ID  EDAD SEXO  CODIGO_DEPARTAMENTO  REGION TIPO_PESCADOR  COBRO  MONTO  \
# 0  1731    25    M                    2  ANCASH     EMBARCADO      1    700
# 1  1362    49    M                    2  ANCASH     EMBARCADO      1    700
# 2  1238    46    M                    2  ANCASH     EMBARCADO      1    700
# 3   354    59    M                    2  ANCASH     EMBARCADO      1    700
# 4   463    58    M                    2  ANCASH     EMBARCADO      1    700
#
#    FECHA_CORTE  FECHA_PUBLICACION_PNDA
# 0     20240228                20240404
# 1     20240228                20240404
# 2     20240228                20240404
# 3     20240228                20240404
# 4     20240228                20240404

# %%
#Si el CSV tiene otro demilimador que no sea ","
#pd.read_csv('Beneficiarios-del-Bono-del-Pescador-2024.csv', sep=',')

# %%
df2.columns
# Out:
# Index(['ID', 'EDAD', 'SEXO', 'CODIGO_DEPARTAMENTO', 'REGION', 'TIPO_PESCADOR',
#        'COBRO', 'MONTO', 'FECHA_CORTE', 'FECHA_PUBLICACION_PNDA'],
#       dtype='object')

# %%
df3=pd.read_json('charactersdataraw.json')
df3
# Out:
#                       Name                                               Link  \
# 0              Mrs. Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 1            Hannah Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 2            Abel Treetops  https://www.hp-lexicon.org/character/abel-tree...
# 3         Euan Abercrombie  https://www.hp-lexicon.org/character/abercromb...
# 4     Aberforth Dumbledore  https://www.hp-lexicon.org/character/dumbledor...
# ...                    ...                                                ...
# 1935        Georgi Zdravko  https://www.hp-lexicon.org/character/georgi-zd...
# 1936                Zograf       https://www.hp-lexicon.org/character/zograf/
# 1937                 Zonko        https://www.hp-lexicon.org/character/zonko/
# 1938     Valentina Vázquez  https://www.hp-lexicon.org/character/valentina...
# 1939         Zygmunt Budge  https://www.hp-lexicon.org/character/zygmunt-b...
#
# ...

# %%
pd.read_json('charactersdataraw.json', typ='Series')
# Out:
# 0       {'Name': 'Mrs. Abbott', 'Link': 'https://www.h...
# 1       {'Name': 'Hannah Abbott', 'Link': 'https://www...
# 2       {'Name': 'Abel Treetops', 'Link': 'https://www...
# 3       {'Name': 'Euan Abercrombie', 'Link': 'https://...
# 4       {'Name': 'Aberforth Dumbledore', 'Link': 'http...
#                               ...
# 1935    {'Name': 'Georgi Zdravko', 'Link': 'https://ww...
# 1936    {'Name': 'Zograf', 'Link': 'https://www.hp-lex...
# 1937    {'Name': 'Zonko', 'Link': 'https://www.hp-lexi...
# 1938    {'Name': 'Valentina Vázquez', 'Link': 'https:/...
# 1939    {'Name': 'Zygmunt Budge', 'Link': 'https://www...
# Length: 1940, dtype: object

# %%
nombres=df1.Name
nombres.head(5)
# Out:
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# Name: Name, dtype: object

# %%
nombres=df1['Name']
nombres.head(5)
# Out:
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# Name: Name, dtype: object

# %%
nombres=df1[['Author','Price']]
nombres.head(5)
# Out:
#                      Author  Price
# 0                  JJ Smith      8
# 1              Stephen King     22
# 2        Jordan B. Peterson     15
# 3             George Orwell      6
# 4  National Geographic Kids     12

# %%
nombres=df1[['Author','Price','Year']]
nombres.head()
# Out:
#                      Author  Price  Year
# 0                  JJ Smith      8  2016
# 1              Stephen King     22  2011
# 2        Jordan B. Peterson     15  2018
# 3             George Orwell      6  2017
# 4  National Geographic Kids     12  2019

# %%
df1.loc[0:2]
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Price  Year        Genre
# 0    17350      8  2016  Non Fiction
# 1     2052     22  2011      Fiction
# 2    18979     15  2018  Non Fiction

# %%
df1.loc[545:,['Author','Year']]
# Out:
#           Author  Year
# 545  Jeff Kinney  2019
# 546  Jen Sincero  2016
# 547  Jen Sincero  2017
# 548  Jen Sincero  2018
# 549  Jen Sincero  2019

# %%
df1.iloc[545:,2:3]
# Out:
#      User Rating
# 545          4.9
# 546          4.7
# 547          4.7
# 548          4.7
# 549          4.7

# %%
df5=df1.drop('Name',axis=1)

# %%
df5
# Out:
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 6 columns]

# %%
df1.isnull().count()
# Out:
# Name           550
# Author         550
# User Rating    550
# Reviews        550
# Price          550
# Year           550
# Genre          550
# dtype: int64

# %%
df2.isnull().count()
# Out:
# ID                        47070
# EDAD                      47070
# SEXO                      47070
# CODIGO_DEPARTAMENTO       47070
# REGION                    47070
# TIPO_PESCADOR             47070
# COBRO                     47070
# MONTO                     47070
# FECHA_CORTE               47070
# FECHA_PUBLICACION_PNDA    47070
# dtype: int64

# %%
df1.isnull().count()

# %%
df1.isnull().sum()
# Out:
# Name           0
# Author         0
# User Rating    0
# Reviews        0
# Price          0
# Year           0
# Genre          0
# dtype: int64

# %%
#LLenar Los valores nulos, para luego filtrarlos
df1.fillna('missing')
df1
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
#Llena Los nulos con interpolación como si fuese una serie
df1.interpolate()
# Out:
# C:\Users\guido\AppData\Local\Temp\ipykernel_5532\960823848.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df1.interpolate()
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
# ...

# %%
#Elimina Las filas con valores nulos
df1.dropna()
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df1['Year']>2016
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 545     True
# 546    False
# 547     True
# 548     True
# 549     True
# Name: Year, Length: 550, dtype: bool

# %%
df8=df1[df1['Year']>2018]
df8
# Out:
#                                                   Name  \
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 33                                            Becoming
# 41            Brown Bear, Brown Bear, What Do You See?
# 44   Can't Hurt Me: Master Your Mind and Defy the Odds
# 74   Difficult Riddles For Smart Kids: 300 Difficul...
# 84   Dog Man: Brawl of the Wild: From the Creator o...
# 85   Dog Man: Fetch-22: From the Creator of Captain...
# 86   Dog Man: For Whom the Ball Rolls: From the Cre...
# 98                                  Educated: A Memoir
# 127                               Giraffes Can't Dance
# 128  Girl, Stop Apologizing: A Shame-Free Plan for ...
# 130  Girl, Wash Your Face: Stop Believing the Lies ...
# 138  Good Days Start With Gratitude: A 52 Week Guid...
# 145                                     Goodnight Moon
# 150                                               Guts
# 155  Harry Potter and the Goblet of Fire: The Illus...
# ...

# %%
#Podemos pasar doble condición
mayor_2016=df_books['Year']>2016
genre_fiction=df_books['Genre'] == 'Fiction'
df_books[mayor_2016 & genre_fiction]
#df_books[(df_books['Year']>2016) & (df_books['Genre'] == 'Fiction')]

# %% [markdown]
# ACTIVIDAD: Filtra los registros para crear un dataset de los
# libros publicados entre los anos 2017 y 2018, y que sean de
# género "Genre".

# %%
entre2017_2018 = df1[(df1['Year'] >= 2017) & (df1['Year'] <= 2018)]
entre2017_2018
# Out:
#                                                   Name  \
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# 10                           A Man Called Ove: A Novel
# ..                                                 ...
# 526                                      What Happened
# 536  Whose Boat Is This Boat?: Comments That Don't ...
# 544                                             Wonder
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
#
#                                Author  User Rating  Reviews  Price  Year  \
# 2                  Jordan B. Peterson          4.7    18979     15  2018
# 3                       George Orwell          4.7    21424      6  2017
# 7                         Amor Towles          4.7    19699     15  2017
# ...

# %%
df10 = df1.loc[df1['Year'].between(2017, 2018)]
df10
# Out:
#                                                   Name  \
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# 10                           A Man Called Ove: A Novel
# ..                                                 ...
# 526                                      What Happened
# 536  Whose Boat Is This Boat?: Comments That Don't ...
# 544                                             Wonder
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
#
#                                Author  User Rating  Reviews  Price  Year  \
# 2                  Jordan B. Peterson          4.7    18979     15  2018
# 3                       George Orwell          4.7    21424      6  2017
# 7                         Amor Towles          4.7    19699     15  2017
# ...

# %%
df11 = df10.loc[df1['Genre'] == "Fiction"]
df11
# Out:
#                                                   Name                 Author  \
# 3                               1984 (Signet Classics)          George Orwell
# 7                       A Gentleman in Moscow: A Novel            Amor Towles
# 10                           A Man Called Ove: A Novel        Fredrik Backman
# 13                    A Wrinkle in Time (Time Quintet)      Madeleine L'Engle
# 40            Brown Bear, Brown Bear, What Do You See?        Bill Martin Jr.
# 53       Crazy Rich Asians (Crazy Rich Asians Trilogy)             Kevin Kwan
# 65                      Dear Zoo: A Lift-the-Flap Book           Rod Campbell
# 66                      Dear Zoo: A Lift-the-Flap Book           Rod Campbell
# 81   Dog Man and Cat Kid: From the Creator of Capta...             Dav Pilkey
# 82   Dog Man: A Tale of Two Kitties: From the Creat...             Dav Pilkey
# 83   Dog Man: Brawl of the Wild: From the Creator o...             Dav Pilkey
# ...

# %%
df11 = df1.loc[(df1['Year'].between(2017, 2018)) & (df1['Genre'] == "Fiction")]
df11()
# Out:
#                                                   Name                 Author  \
# 3                               1984 (Signet Classics)          George Orwell
# 7                       A Gentleman in Moscow: A Novel            Amor Towles
# 10                           A Man Called Ove: A Novel        Fredrik Backman
# 13                    A Wrinkle in Time (Time Quintet)      Madeleine L'Engle
# 40            Brown Bear, Brown Bear, What Do You See?        Bill Martin Jr.
# 53       Crazy Rich Asians (Crazy Rich Asians Trilogy)             Kevin Kwan
# 65                      Dear Zoo: A Lift-the-Flap Book           Rod Campbell
# 66                      Dear Zoo: A Lift-the-Flap Book           Rod Campbell
# 81   Dog Man and Cat Kid: From the Creator of Capta...             Dav Pilkey
# 82   Dog Man: A Tale of Two Kitties: From the Creat...             Dav Pilkey
# 83   Dog Man: Brawl of the Wild: From the Creator o...             Dav Pilkey
# ...

# %%
df11.count()
# Out:
# Name           45
# Author         45
# User Rating    45
# Reviews        45
# Price          45
# Year           45
# Genre          45
# dtype: int64

# %%
df12=df1[(df1['Year'].isin([2017,2018])) & (df1['Genre']=='Fiction')]
df12.shape
# Out:
# (45, 7)
